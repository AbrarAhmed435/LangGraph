# %% [markdown]
# Memory Store

# %%
from langgraph.store.memory import InMemoryStore
in_memory_store=InMemoryStore()

# %%
#Memories are namespaced by a tuple, which in this specific example will be (<user_id>, "memories"). The namespace can be any length and represent anything, does not have to be user specific.

user_id="1"
namespace_for_memory=(user_id,"memories")

# %%
# to save memory
import uuid
memory_id=str(uuid.uuid4())
memory={
    "food_preference":"I like pizza"
}
in_memory_store.put(namespace_for_memory,memory_id,memory)

# %%
memories=in_memory_store.search(namespace_for_memory)

# %%
memories
# Out:
# [Item(namespace=['1', 'memories'], key='dcf0eaef-d5d5-41e4-a2c3-b5e68b5d3081', value={'food_preference': 'I like pizza'}, created_at='2026-01-29T12:44:20.501627+00:00', updated_at='2026-01-29T12:44:20.501629+00:00', score=None),
#  Item(namespace=['1', 'memories'], key='e71da7d6-005b-41a4-afb5-58958e0806cc', value={'food_preference': 'I like pizza'}, created_at='2026-01-29T12:44:53.455376+00:00', updated_at='2026-01-29T12:44:53.455378+00:00', score=None)]

# %%
#latest memory is at last
memories[-1].dict()
# Out:
# {'namespace': ['1', 'memories'],
#  'key': 'e71da7d6-005b-41a4-afb5-58958e0806cc',
#  'value': {'food_preference': 'I like pizza'},
#  'created_at': '2026-01-29T12:44:53.455376+00:00',
#  'updated_at': '2026-01-29T12:44:53.455378+00:00',
#  'score': None}

# %%
in_memory_store.put(namespace_for_memory,str(uuid.uuid4()),{"name":"Khan_sahab"})

# %%
memories=in_memory_store.search(namespace_for_memory)
memories
# Out:
# [Item(namespace=['1', 'memories'], key='dcf0eaef-d5d5-41e4-a2c3-b5e68b5d3081', value={'food_preference': 'I like pizza'}, created_at='2026-01-29T12:44:20.501627+00:00', updated_at='2026-01-29T12:44:20.501629+00:00', score=None),
#  Item(namespace=['1', 'memories'], key='e71da7d6-005b-41a4-afb5-58958e0806cc', value={'food_preference': 'I like pizza'}, created_at='2026-01-29T12:44:53.455376+00:00', updated_at='2026-01-29T12:44:53.455378+00:00', score=None),
#  Item(namespace=['1', 'memories'], key='b961a467-73b9-4c95-8565-f7e0aa8e10c9', value={'name': 'Khan_sahab'}, created_at='2026-01-29T12:45:05.686407+00:00', updated_at='2026-01-29T12:45:05.686409+00:00', score=None)]

# %%
in_memory_store.put(namespace_for_memory,str(uuid.uuid4()),{"name":"Khan_sahab"})
memories=in_memory_store.search(namespace_for_memory)
memories
# Out:
# [Item(namespace=['1', 'memories'], key='dcf0eaef-d5d5-41e4-a2c3-b5e68b5d3081', value={'food_preference': 'I like pizza'}, created_at='2026-01-29T12:44:20.501627+00:00', updated_at='2026-01-29T12:44:20.501629+00:00', score=None),
#  Item(namespace=['1', 'memories'], key='e71da7d6-005b-41a4-afb5-58958e0806cc', value={'food_preference': 'I like pizza'}, created_at='2026-01-29T12:44:53.455376+00:00', updated_at='2026-01-29T12:44:53.455378+00:00', score=None),
#  Item(namespace=['1', 'memories'], key='b961a467-73b9-4c95-8565-f7e0aa8e10c9', value={'name': 'Khan_sahab'}, created_at='2026-01-29T12:45:05.686407+00:00', updated_at='2026-01-29T12:45:05.686409+00:00', score=None),
#  Item(namespace=['1', 'memories'], key='4d4756ca-4bc0-48b0-9476-ef3beae27891', value={'name': 'Khan_sahab'}, created_at='2026-01-29T12:45:41.458214+00:00', updated_at='2026-01-29T12:45:41.458216+00:00', score=None)]
