# %% [markdown]
# Memory Store

# %%
from langgraph.store.memory import InMemoryStore
in_memory_store=InMemoryStore()

# %%
# Memories are namespaced by a tuple, which in this specific example will be (<user_id>, "memories"). The namespace can be any length and represent anything, does not have to be user specific.

user_id="1"
namespace_for_memory=(user_id,"memories")

# %%
# to save memory
import uuid
memory_id=str(uuid.uuid4())
memory={
    "food_preference":"I like pizza"
}
in_memory_store.put(namespace_for_memory,memory_id,memory)

# %%
memories=in_memory_store.search(namespace_for_memory)

# %%
memories
# Out:
# [Item(namespace=['1', 'memories'], key='addceebb-0c82-48b4-8acc-87a1b023acea', value={'food_preference': 'I like pizza'}, created_at='2026-04-01T03:33:44.350202+00:00', updated_at='2026-04-01T03:33:44.350206+00:00', score=None)]

# %%
#latest memory is at last
memories[-1].dict()
# Out:
# {'namespace': ['1', 'memories'],
#  'key': 'addceebb-0c82-48b4-8acc-87a1b023acea',
#  'value': {'food_preference': 'I like pizza'},
#  'created_at': '2026-04-01T03:33:44.350202+00:00',
#  'updated_at': '2026-04-01T03:33:44.350206+00:00',
#  'score': None}

# %%
in_memory_store.put(namespace_for_memory,str(uuid.uuid4()),{"name":"Khan_sahab"})

# %%
memories=in_memory_store.search(namespace_for_memory)
memories
# Out:
# [Item(namespace=['1', 'memories'], key='addceebb-0c82-48b4-8acc-87a1b023acea', value={'food_preference': 'I like pizza'}, created_at='2026-04-01T03:33:44.350202+00:00', updated_at='2026-04-01T03:33:44.350206+00:00', score=None),
#  Item(namespace=['1', 'memories'], key='4fef3f70-f893-4641-806c-101f390d41a6', value={'name': 'Khan_sahab'}, created_at='2026-04-01T03:34:30.094002+00:00', updated_at='2026-04-01T03:34:30.094005+00:00', score=None)]

# %%
memories[-1].dict()
# Out:
# {'namespace': ['1', 'memories'],
#  'key': '4fef3f70-f893-4641-806c-101f390d41a6',
#  'value': {'name': 'Khan_sahab'},
#  'created_at': '2026-04-01T03:34:30.094002+00:00',
#  'updated_at': '2026-04-01T03:34:30.094005+00:00',
#  'score': None}

# %%
in_memory_store.put(namespace_for_memory,str(uuid.uuid4()),{"name":"Khan_sahab"})
memories=in_memory_store.search(namespace_for_memory)
memories

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings

embedding = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# result = embedding.embed_query("Delhi is capital of India")
# print(result[1:10])
# Out:
# /tmp/ipykernel_5753/1746579968.py:3: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding = HuggingFaceEmbeddings(
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Desktop/Abrar/LangGraph/env_langgraph/lib/python3.12/site-packages/langchain_community/embeddings/huggingface.py:84, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      83 try:
# ---> 84     import sentence_transformers
#      86 except ImportError as exc:
#
# ModuleNotFoundError: No module named 'sentence_transformers'
#
# ...

# %% [markdown]
# SEMANTIC SEARCH

# %%
from langchain.embeddings import init_embeddings

new_store=InMemoryStore(
    index={
        "embed":init_embeddings("embedding"),
        "fields":["food_preference"]
    }
)
