# %% [markdown]
# Memory Store

# %%
from langgraph.store.memory import InMemoryStore
in_memory_store=InMemoryStore()

# %%
#Memories are namespaced by a tuple, which in this specific example will be (<user_id>, "memories"). The namespace can be any length and represent anything, does not have to be user specific.

user_id="1"
namespace_for_memory=(user_id,"memories")

# %%
# to save memory
import uuid
memory_id=str(uuid.uuid4())
memory={
    "food_preference":"I like pizza"
}
in_memory_store.put(namespace_for_memory,memory_id,memory)

# %%
memories=in_memory_store.search(namespace_for_memory)

# %%
memories
# Out:
# [Item(namespace=['1', 'memories'], key='83df8cdf-6131-44b9-a3cf-a0864581ba28', value={'food_preference': 'I like pizza'}, created_at='2026-01-28T19:23:15.160868+00:00', updated_at='2026-01-28T19:23:15.160872+00:00', score=None)]

# %%
memories[-1].dict()
# Out:
# {'namespace': ['1', 'memories'],
#  'key': '83df8cdf-6131-44b9-a3cf-a0864581ba28',
#  'value': {'food_preference': 'I like pizza'},
#  'created_at': '2026-01-28T19:23:15.160868+00:00',
#  'updated_at': '2026-01-28T19:23:15.160872+00:00',
#  'score': None}

# %%
in_memory_store.put(namespace_for_memory,str(uuid.uuid4()),{"name":"Khan_sahab"})

# %%
memories=in_memory_store.search(namespace_for_memory)
memories
# Out:
# [Item(namespace=['1', 'memories'], key='83df8cdf-6131-44b9-a3cf-a0864581ba28', value={'food_preference': 'I like pizza'}, created_at='2026-01-28T19:23:15.160868+00:00', updated_at='2026-01-28T19:23:15.160872+00:00', score=None),
#  Item(namespace=['1', 'memories'], key='1a086f46-a555-4619-beae-07c4fdcdd22d', value={'name': 'Khan_sahab'}, created_at='2026-01-28T19:23:15.194679+00:00', updated_at='2026-01-28T19:23:15.194682+00:00', score=None)]

# %%
in_memory_store.put(namespace_for_memory,str(uuid.uuid4()),{"name":"Khan_sahab"})
memories=in_memory_store.search(namespace_for_memory)
memories
# Out:
# [Item(namespace=['1', 'memories'], key='83df8cdf-6131-44b9-a3cf-a0864581ba28', value={'food_preference': 'I like pizza'}, created_at='2026-01-28T19:23:15.160868+00:00', updated_at='2026-01-28T19:23:15.160872+00:00', score=None),
#  Item(namespace=['1', 'memories'], key='1a086f46-a555-4619-beae-07c4fdcdd22d', value={'name': 'Khan_sahab'}, created_at='2026-01-28T19:23:15.194679+00:00', updated_at='2026-01-28T19:23:15.194682+00:00', score=None),
#  Item(namespace=['1', 'memories'], key='71121387-3a12-4209-bd81-7f03800574a6', value={'name': 'Khan_sahab'}, created_at='2026-01-28T19:25:42.208849+00:00', updated_at='2026-01-28T19:25:42.208850+00:00', score=None)]
